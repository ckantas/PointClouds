# %%
import numpy as np
import open3d as o3d
import copy
import pickle
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
import time
from scipy.spatial import cKDTree
from joblib import Parallel, delayed

from OCC.Core.STEPControl import STEPControl_Reader
from OCC.Core.IFSelect import IFSelect_RetDone
from OCC.Core.TopAbs import TopAbs_WIRE, TopAbs_EDGE, TopAbs_VERTEX
from OCC.Core.TopExp import TopExp_Explorer
from OCC.Core.TopoDS import topods
from OCC.Core.BRep import BRep_Tool
from OCC.Core.BRepAdaptor import BRepAdaptor_Curve
from OCC.Core.GeomAbs import GeomAbs_Circle, GeomAbs_Ellipse, GeomAbs_Line, GeomAbs_BSplineCurve, GeomAbs_Hyperbola, GeomAbs_Parabola
from OCC.Core.TopAbs import TopAbs_WIRE, TopAbs_EDGE, TopAbs_VERTEX
from OCC.Display.SimpleGui import init_display
from OCC.Core.Quantity import Quantity_Color, Quantity_TOC_RGB
from OCC.Core.gp import gp_Pnt
from OCC.Core.BRepBuilderAPI import BRepBuilderAPI_MakeVertex
from PyQt5 import QtWidgets
from OCC.Core.GCPnts import GCPnts_UniformDeflection
from OCC.Core.GProp import GProp_GProps
from OCC.Core.BRepGProp import brepgprop
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
# Read processed point cloud data

point_dictionary_path = '/home/chris/Code/PointClouds/data/hull_pcd/morten_plate/mapped_hull_points_dictionary.pkl'

hull_centers_dictionary = {}

with open(point_dictionary_path, 'rb') as f:
    hull_points_dictionary = pickle.load(f)

hull_pcd = o3d.geometry.PointCloud()

for label, points in hull_points_dictionary.items():
    hull_pcd.points.extend(o3d.utility.Vector3dVector(points))
    center = np.mean(points, axis=0)
    hull_centers_dictionary[label] = center
    
hull_pcd.paint_uniform_color([0.1, 1, 0.1])

hull_centers_pcd = o3d.geometry.PointCloud()
hull_centers_points = list(hull_centers_dictionary.values())
hull_centers_pcd.points = o3d.utility.Vector3dVector(np.array(hull_centers_points))
hull_centers_pcd.paint_uniform_color([1, 0, 0])  # Color centers red

print("Point cloud data has been loaded successfully.")
# Out:
# Point cloud data has been loaded successfully.

# %%
# Read cad model data (STEP file)

step_file_path = '/home/chris/Code/PointClouds/data/other_files/MortenPartSTEPVersion.STEP'

def load_step_file(file_path):
    step_reader = STEPControl_Reader()
    status = step_reader.ReadFile(file_path)
    if status == IFSelect_RetDone:
        step_reader.TransferRoots()
        shape = step_reader.OneShape()
        return shape
    else:
        raise Exception("Error: Cannot read STEP file.")

shape = load_step_file(step_file_path)

print('Step file has been loaded successfully.')
# Out:
# Step file has been loaded successfully.

# %%
# Extract edges at the top Z-coordinate
def extract_top_edges(shape, deflection=0.1):
    edges = []
    max_z = -float('inf')
    edge_z_coordinates = []

    # First pass to collect the highest Z-coordinate of each edge
    exp_edge = TopExp_Explorer(shape, TopAbs_EDGE)
    while exp_edge.More():
        edge = topods.Edge(exp_edge.Current())
        edge_max_z = -float('inf')
        exp_vertex = TopExp_Explorer(edge, TopAbs_VERTEX)
        vertices = []
        while exp_vertex.More():
            vertex = topods.Vertex(exp_vertex.Current())
            point = BRep_Tool.Pnt(vertex)
            vertices.append(point)
            if point.Z() > edge_max_z:
                edge_max_z = point.Z()
            exp_vertex.Next()
        edge_z_coordinates.append((edge, edge_max_z, vertices))
        if edge_max_z > max_z:
            max_z = edge_max_z
        exp_edge.Next()

    #print(f"Total number of edges: {len(edge_z_coordinates)}")
    #print(f"Maximum Z-coordinate found: {max_z}")

    # Collect edges on the top plane
    top_edges = []
    point_cloud = []
    for edge, z, vertices in edge_z_coordinates:
        if all(abs(vertex.Z() - max_z) < 1e-3 for vertex in vertices):  # Ensure all vertices are at the top surface
            top_edges.append(edge)
            #print(f"Top edge added with highest vertex Z: {z}")

            # Sample points along the edge
            curve = BRepAdaptor_Curve(edge)
            u_min, u_max = curve.FirstParameter(), curve.LastParameter()

            # Calculate the length of the edge
            linear_props = GProp_GProps()
            brepgprop.LinearProperties(edge, linear_props)
            length = linear_props.Mass()

            # Calculate the number of samples based on the length and the desired point density
            num_samples = int(length / deflection)

            for i in range(num_samples):
                u = u_min + i * (u_max - u_min) / (num_samples - 1)
                pnt = curve.Value(u)
                point_cloud.append((pnt.X(), pnt.Y(), pnt.Z()))  # Store the coordinates as a tuple

    print(f"Total number of top view edges: {len(top_edges)}")
    print(f"Total number of points in the cad point cloud: {len(point_cloud)}")
    return top_edges, point_cloud

# Visualize the top edges
def visualize_top_edges(top_edges):
    display, start_display, add_menu, add_function_to_menu = init_display()

    # Assign the color red to each top edge
    red_color = Quantity_Color(1.0, 0.0, 0.0, Quantity_TOC_RGB)
    
    # Display each top edge with the red color
    for edge in top_edges:
        display.DisplayShape(edge, update=True, color=red_color)

    start_display()


# Main execution
print('Generating top view edges and sampling to create the associated point cloud...')
top_edges, cad_points = extract_top_edges(shape)
# if top_edges:
#     visualize_top_edges(top_edges)
# else:
#     print("Top edges not found.")

cad_pcd = o3d.geometry.PointCloud()
cad_pcd.points = o3d.utility.Vector3dVector(np.asarray(cad_points))
#o3d.visualization.draw_geometries([cad_pcd])

print('Top view cad point cloud created.')
# Out:
# Generating top view edges and sampling to create the associated point cloud...
# Total number of top view edges: 586
# Total number of points in the cad point cloud: 81774
# Top view cad point cloud created.

# %%
# Apply clustering to the cad_pcd

eps = 0.50
min_points = 10

cad_shapes_labels = np.array(cad_pcd.cluster_dbscan(eps=eps, min_points=min_points, print_progress=True))

max_label = cad_shapes_labels.max()
print(f"Cad point cloud has {max_label + 1} clusters")
base_cmap = plt.get_cmap("tab20")
color_cycle = [base_cmap(i % 20) for i in range(max_label + 1)]
colors = np.array(color_cycle)[cad_shapes_labels]
colors[cad_shapes_labels<0] = 0
cad_pcd.colors = o3d.utility.Vector3dVector(colors[:, :3])

cad_points_dictionary = {}
cad_centers_dictionary = {}

# Extract the points and calculate the centers for each cluster
for label in np.unique(cad_shapes_labels):
    if label != -1:  # Ignore noise
        cluster_points = np.asarray(cad_pcd.points)[cad_shapes_labels == label]
        cad_points_dictionary[label] = cluster_points
        cad_centers_dictionary[label] = np.mean(cluster_points, axis=0)

cad_centers_pcd = o3d.geometry.PointCloud()
cad_centers_points = list(cad_centers_dictionary.values())
cad_centers_pcd.points = o3d.utility.Vector3dVector(np.array(cad_centers_points))
cad_centers_pcd.paint_uniform_color([0, 1, 0])  # Color centers green

#o3d.visualization.draw_geometries([cad_pcd])
# Out:
# Precompute neighbors.[========================================] 100%
# ClusteringCad point cloud has 79 clusters          ] 15%
# Clustering[========================================] 100%
# PointCloud with 79 points.

# %%
# Center based alignment: Align point clouds through ICP based on the lowest RMSE (only use centers of shapes)

cad_centers_pcd_center = np.mean(np.asarray(cad_centers_pcd.points), axis=0)
hull_centers_pcd_center = np.mean(np.asarray(hull_centers_pcd.points), axis=0)

# Compute the translation vector
translation = cad_centers_pcd_center - hull_centers_pcd_center

# Translate the hull_pcd to align the centers
hull_centers_pcd.points = o3d.utility.Vector3dVector(np.asarray(hull_centers_pcd.points) + translation)

#o3d.visualization.draw_geometries([cad_centers_pcd, hull_centers_pcd])

# %%
visualization = o3d.visualization.VisualizerWithKeyCallback()
visualization.create_window()
visualization.get_render_option().background_color = np.asarray([0.95, 0.95, 0.95])

class RansacState:
    def __init__(self, pcd_A, pcd_B):
        print('Initializing Parameters:')
        print(30*'-')

        self.pcd_A = pcd_A
        self.pcd_B = pcd_B

        self.cloud_A_points = np.asarray(pcd_A.points)[:, :2]
        self.cloud_B_points = np.asarray(pcd_B.points)[:, :2]

        self.pcd_A_colors = np.tile((0.1,0.9,0.1), (self.cloud_A_points.shape[0], 1))
        self.pcd_B_colors = np.tile((0.1,0.1,0.9), (self.cloud_B_points.shape[0], 1))

        print(f'cloud_A shape: {self.cloud_A_points.shape}')
        print(f'cloud_B shape: {self.cloud_B_points.shape}')

        self.cloud_A_indices = np.arange(self.cloud_A_points.shape[0])
        self.cloud_B_indices = np.arange(self.cloud_B_points.shape[0])
        
        self.changing_angle = False
        self.picked_pair = None
        self.added_geometries = False
        self.current_angle_idx = 0
        self.it = -1

        self.angles = np.arange(-np.pi/2, np.pi/2, np.pi/720)
        print(30*'-')

        combinations = np.array(np.meshgrid(self.cloud_A_indices, self.cloud_B_indices)).T.reshape(-1, 2)
        self.shuffled_combinations = np.random.permutation(combinations)
        print(f'shuffled_combinations shape: {self.shuffled_combinations.shape}')
        print('printing the first five elements from shuffled_combinations:')
        for i in range(5):
            print(self.shuffled_combinations[i])
        print(30*'-')

        self.translations = self.cloud_B_points[self.shuffled_combinations[:, 1]] - self.cloud_A_points[self.shuffled_combinations[:, 0]]
        print(f'translations shape {self.translations.shape}')
        print('printing the first five elements of translations:')
        for i in range(5):
            print(self.translations[i])
        print(30*'-')

        self.translated_clouds = self.cloud_A_points[np.newaxis, :, :] + self.translations[:, np.newaxis, :]
        self.centering_vectors = self.cloud_B_points[self.shuffled_combinations[:, 1]]
        self.centered_clouds = self.translated_clouds - self.centering_vectors[:, np.newaxis, :]

        print(f'translated_clouds shape: {self.translated_clouds.shape}')
        print(f'centered_clouds shape: {self.centered_clouds.shape}')
        print(30*'-')
        return
    
    def get_rotation_matrix(self,angle):
        return np.array([[np.cos(angle), -np.sin(angle)], [np.sin(angle), np.cos(angle)]])

    def apply_single_rotation(self, centered_cloud, angle):
        rotation_matrix = self.get_rotation_matrix(angle)
        rotated_cloud = np.dot(centered_cloud, rotation_matrix.T)
        return rotated_cloud

    def calculate_distances_optimized(self, rotated_cloud, cloud_B):
        tree = cKDTree(cloud_B)
        distances, _ = tree.query(rotated_cloud)
        return distances
    
    def pair_points_forward_callback(self, vis):
        if self.added_geometries is False:
            self.pcd_A.colors = o3d.utility.Vector3dVector(self.pcd_A_colors)
            self.pcd_B.colors = o3d.utility.Vector3dVector(self.pcd_B_colors)
            visualization.add_geometry(self.pcd_A)
            visualization.add_geometry(self.pcd_B)
            self.added_geometries = True
            return
        else:
            self.it += 1
            new_pcd_A_points = self.translated_clouds[self.it]
            new_pcd_A_points_3d = np.hstack((new_pcd_A_points, np.full((new_pcd_A_points.shape[0], 1), 2)))
            self.pcd_A.points = o3d.utility.Vector3dVector(new_pcd_A_points_3d)
            self.picked_pair = self.shuffled_combinations[self.it]
            self.pcd_A_colors[self.picked_pair[0]] = (0.9, 0.1, 0.1)
            self.pcd_B_colors[self.picked_pair[1]] = (0.9, 0.1, 0.1)
            self.pcd_A.colors = o3d.utility.Vector3dVector(self.pcd_A_colors)
            self.pcd_B.colors = o3d.utility.Vector3dVector(self.pcd_B_colors)
            vis.update_geometry(self.pcd_A)
            vis.update_geometry(self.pcd_B)
            self.pcd_A_colors[self.picked_pair[0]] = (0.1, 0.9, 0.1)
            self.pcd_B_colors[self.picked_pair[1]] = (0.1, 0.1, 0.9)
            self.current_angle_idx = 0
            self.changing_angle = False
        return
    
    def pair_points_backward_callback(self, vis):
        if self.added_geometries and self.it >= 1:
            self.it -= 1
            new_pcd_A_points = self.translated_clouds[self.it]
            new_pcd_A_points_3d = np.hstack((new_pcd_A_points, np.full((new_pcd_A_points.shape[0], 1), 2)))
            self.pcd_A.points = o3d.utility.Vector3dVector(new_pcd_A_points_3d)
            self.picked_pair = self.shuffled_combinations[self.it]
            self.pcd_A_colors[self.picked_pair[0]] = (0.9, 0.1, 0.1)
            self.pcd_B_colors[self.picked_pair[1]] = (0.9, 0.1, 0.1)
            self.pcd_A.colors = o3d.utility.Vector3dVector(self.pcd_A_colors)
            self.pcd_B.colors = o3d.utility.Vector3dVector(self.pcd_B_colors)
            vis.update_geometry(self.pcd_A)
            vis.update_geometry(self.pcd_B)
            self.pcd_A_colors[self.picked_pair[0]] = (0.1, 0.9, 0.1)
            self.pcd_B_colors[self.picked_pair[1]] = (0.1, 0.1, 0.9)
            self.current_angle_idx = 0
            self.changing_angle = False
        return
    
    def rotate_cloud_forward_callback(self, vis):
        if self.changing_angle == False:
            angle = self.angles[self.current_angle_idx]
            centered_cloud = self.centered_clouds[self.it]
            centering_vector = self.centering_vectors[self.it]

            rotated_cloud = self.apply_single_rotation(centered_cloud, angle)
            uncentered_rotated_cloud = rotated_cloud + centering_vector

            distances = self.calculate_distances_optimized(uncentered_rotated_cloud, self.cloud_B_points)
            avg_distance = np.mean(distances)
            print(f"Angle: {angle:.2f} radians, Average Distance: {avg_distance:.4f}", flush=True)
            uncentered_rotated_cloud_3d = np.hstack((uncentered_rotated_cloud, np.full((uncentered_rotated_cloud.shape[0], 1), 2)))
            self.pcd_A.points = o3d.utility.Vector3dVector(uncentered_rotated_cloud_3d)
            vis.update_geometry(self.pcd_A)
            self.changing_angle = True
            return
        
        if self.it != 0 and (self.current_angle_idx < self.angles.shape[0]):
            self.current_angle_idx += 1
            angle = self.angles[self.current_angle_idx]
            centered_cloud = self.centered_clouds[self.it]
            centering_vector = self.centering_vectors[self.it]

            rotated_cloud = self.apply_single_rotation(centered_cloud, angle)
            uncentered_rotated_cloud = rotated_cloud + centering_vector

            distances = self.calculate_distances_optimized(uncentered_rotated_cloud, self.cloud_B_points)
            avg_distance = np.mean(distances)
            print(f"Angle: {angle:.2f} radians, Average Distance: {avg_distance:.4f}", flush=True)
            uncentered_rotated_cloud_3d = np.hstack((uncentered_rotated_cloud, np.full((uncentered_rotated_cloud.shape[0], 1), 2)))
            self.pcd_A.points = o3d.utility.Vector3dVector(uncentered_rotated_cloud_3d)
            vis.update_geometry(self.pcd_A)
        return
    
    def rotate_cloud_backward_callback(self, vis):
        if self.it != 0 and (self.current_angle_idx > 0) and self.changing_angle:
            self.current_angle_idx -= 1
            angle = self.angles[self.current_angle_idx]
            centered_cloud = self.centered_clouds[self.it]
            centering_vector = self.centering_vectors[self.it]

            rotated_cloud = self.apply_single_rotation(centered_cloud, angle)
            uncentered_rotated_cloud = rotated_cloud + centering_vector

            distances = self.calculate_distances_optimized(uncentered_rotated_cloud, self.cloud_B_points)
            avg_distance = np.mean(distances)
            print(f"Angle: {angle:.2f} radians, Average Distance: {avg_distance:.4f}", flush=True)
            uncentered_rotated_cloud_3d = np.hstack((uncentered_rotated_cloud, np.full((uncentered_rotated_cloud.shape[0], 1), 2)))
            self.pcd_A.points = o3d.utility.Vector3dVector(uncentered_rotated_cloud_3d)
            vis.update_geometry(self.pcd_A)
        return

state = RansacState(cad_centers_pcd, hull_centers_pcd)
visualization.register_key_callback(262, state.pair_points_forward_callback)
visualization.register_key_callback(263, state.pair_points_backward_callback)
visualization.register_key_callback(265, state.rotate_cloud_forward_callback)
visualization.register_key_callback(264, state.rotate_cloud_backward_callback)
visualization.run()
visualization.destroy_window()
# Out:
# Initializing Parameters:
# ------------------------------
# cloud_A shape: (79, 2)
# cloud_B shape: (75, 2)
# ------------------------------
# shuffled_combinations shape: (5925, 2)
# printing the first five elements from shuffled_combinations:
# [14  5]
# [56 24]
# [ 3 72]
# [29 32]
# [ 5 48]
# ------------------------------
# translations shape (5925, 2)
# printing the first five elements of translations:
# [-81.31816911  96.16226572]
# [-84.28340281 128.35110426]
# [118.76551141  -1.07195402]
# [ 3.49600014 50.47015615]
# [57.38067023 91.25091388]
# ------------------------------
# translated_clouds shape: (5925, 79, 2)
# centered_clouds shape: (5925, 79, 2)
# ------------------------------
# Angle: -1.57 radians, Average Distance: 30.9198
# Angle: -1.57 radians, Average Distance: 30.8476
# Angle: -1.56 radians, Average Distance: 30.7708
# Angle: -1.56 radians, Average Distance: 30.6897
# Angle: -1.55 radians, Average Distance: 30.6095
# Angle: -1.55 radians, Average Distance: 30.5310
# Angle: -1.54 radians, Average Distance: 30.4524
# Angle: -1.54 radians, Average Distance: 30.3771
# Angle: -1.54 radians, Average Distance: 30.3051
# Angle: -1.53 radians, Average Distance: 30.2366
# Angle: -1.53 radians, Average Distance: 30.1717
# Angle: -1.52 radians, Average Distance: 30.1103
# Angle: -1.52 radians, Average Distance: 30.0527
# Angle: -1.51 radians, Average Distance: 29.9990
# Angle: -1.51 radians, Average Distance: 29.9496
# Angle: -1.51 radians, Average Distance: 29.9011
# Angle: -1.50 radians, Average Distance: 29.8553
# Angle: -1.50 radians, Average Distance: 29.8098
# Angle: -1.49 radians, Average Distance: 29.7636
# Angle: -1.49 radians, Average Distance: 29.7190
# Angle: -1.48 radians, Average Distance: 29.6760
# Angle: -1.48 radians, Average Distance: 29.6365
# Angle: -1.47 radians, Average Distance: 29.6004
# Angle: -1.47 radians, Average Distance: 29.5671
# Angle: -1.47 radians, Average Distance: 29.5337
# Angle: -1.46 radians, Average Distance: 29.5047
# Angle: -1.46 radians, Average Distance: 29.4710
# Angle: -1.45 radians, Average Distance: 29.4263
# Angle: -1.45 radians, Average Distance: 29.3839
# Angle: -1.44 radians, Average Distance: 29.3382
# Angle: -1.44 radians, Average Distance: 29.2958
# Angle: -1.44 radians, Average Distance: 29.2529
# Angle: -1.43 radians, Average Distance: 29.2110
# Angle: -1.43 radians, Average Distance: 29.1630
# Angle: -1.42 radians, Average Distance: 29.1115
# Angle: -1.42 radians, Average Distance: 29.0631
# Angle: -1.41 radians, Average Distance: 29.0177
# Angle: -1.41 radians, Average Distance: 28.9754
# Angle: -1.40 radians, Average Distance: 28.9360
# Angle: -1.40 radians, Average Distance: 28.8994
# Angle: -1.40 radians, Average Distance: 28.8617
# Angle: -1.39 radians, Average Distance: 28.8235
# Angle: -1.39 radians, Average Distance: 28.7862
# Angle: -1.38 radians, Average Distance: 28.7505
# Angle: -1.38 radians, Average Distance: 28.7175
# Angle: -1.37 radians, Average Distance: 28.6850
# Angle: -1.37 radians, Average Distance: 28.6517
# Angle: -1.37 radians, Average Distance: 28.6207
# Angle: -1.36 radians, Average Distance: 28.5921
# Angle: -1.36 radians, Average Distance: 28.5661
# Angle: -1.35 radians, Average Distance: 28.5393
# Angle: -1.35 radians, Average Distance: 28.5182
# Angle: -1.34 radians, Average Distance: 28.5025
# Angle: -1.34 radians, Average Distance: 28.4849
# Angle: -1.34 radians, Average Distance: 28.4680
# Angle: -1.33 radians, Average Distance: 28.4521
# Angle: -1.33 radians, Average Distance: 28.4379
# Angle: -1.32 radians, Average Distance: 28.4266
# Angle: -1.32 radians, Average Distance: 28.4167
# Angle: -1.31 radians, Average Distance: 28.4070
# Angle: -1.31 radians, Average Distance: 28.3993
# Angle: -1.30 radians, Average Distance: 28.3943
# Angle: -1.30 radians, Average Distance: 28.3918
# Angle: -1.30 radians, Average Distance: 28.3912
# Angle: -1.29 radians, Average Distance: 28.3904
# Angle: -1.29 radians, Average Distance: 28.3828
# Angle: -1.28 radians, Average Distance: 28.3754
# Angle: -1.28 radians, Average Distance: 28.3676
# Angle: -1.27 radians, Average Distance: 28.3566
# Angle: -1.27 radians, Average Distance: 28.3324
# Angle: -1.27 radians, Average Distance: 28.3049
# Angle: -1.26 radians, Average Distance: 28.2802
# Angle: -1.26 radians, Average Distance: 28.2583
# Angle: -1.25 radians, Average Distance: 28.2391
# Angle: -1.25 radians, Average Distance: 28.2211
# Angle: -1.24 radians, Average Distance: 28.2049
# Angle: -1.24 radians, Average Distance: 28.1848
# Angle: -1.23 radians, Average Distance: 28.1655
# Angle: -1.23 radians, Average Distance: 28.1426
# Angle: -1.23 radians, Average Distance: 28.1175
# Angle: -1.22 radians, Average Distance: 28.0938
# Angle: -1.22 radians, Average Distance: 28.0662
# Angle: -1.21 radians, Average Distance: 28.0383
# Angle: -1.21 radians, Average Distance: 28.0095
# Angle: -1.20 radians, Average Distance: 27.9777
# Angle: -1.20 radians, Average Distance: 27.9448
# Angle: -1.20 radians, Average Distance: 27.9097
# Angle: -1.19 radians, Average Distance: 27.8740
# Angle: -1.19 radians, Average Distance: 27.8333
# Angle: -1.18 radians, Average Distance: 27.7865
# Angle: -1.18 radians, Average Distance: 27.7386
# Angle: -1.17 radians, Average Distance: 27.6907
# Angle: -1.17 radians, Average Distance: 27.6452
# Angle: -1.17 radians, Average Distance: 27.5979
# Angle: -1.16 radians, Average Distance: 27.5448
# Angle: -1.16 radians, Average Distance: 27.4881
# Angle: -1.15 radians, Average Distance: 27.4304
# Angle: -1.15 radians, Average Distance: 27.3667
# Angle: -1.14 radians, Average Distance: 27.3002
# Angle: -1.14 radians, Average Distance: 27.2277
# Angle: -1.13 radians, Average Distance: 27.1532
# Angle: -1.13 radians, Average Distance: 27.0801
# Angle: -1.13 radians, Average Distance: 27.0060
# Angle: -1.12 radians, Average Distance: 26.9139
# Angle: -1.12 radians, Average Distance: 26.8182
# Angle: -1.11 radians, Average Distance: 26.7253
# Angle: -1.11 radians, Average Distance: 26.6305
# Angle: -1.10 radians, Average Distance: 26.5314
# Angle: -1.10 radians, Average Distance: 26.4304
# Angle: -1.10 radians, Average Distance: 26.3327
# Angle: -1.09 radians, Average Distance: 26.2383
# Angle: -1.09 radians, Average Distance: 26.1453
# Angle: -1.08 radians, Average Distance: 26.0453
# Angle: -1.08 radians, Average Distance: 25.9462
# Angle: -1.07 radians, Average Distance: 25.8491
# Angle: -1.07 radians, Average Distance: 25.7545
# Angle: -1.06 radians, Average Distance: 25.6639
# Angle: -1.06 radians, Average Distance: 25.5772
# Angle: -1.06 radians, Average Distance: 25.4928
# Angle: -1.05 radians, Average Distance: 25.4075
# Angle: -1.05 radians, Average Distance: 25.3200
# Angle: -1.04 radians, Average Distance: 25.2352
# Angle: -1.04 radians, Average Distance: 25.1540
# Angle: -1.03 radians, Average Distance: 25.0673
# Angle: -1.03 radians, Average Distance: 24.9713
# Angle: -1.03 radians, Average Distance: 24.8747
# Angle: -1.02 radians, Average Distance: 24.7819
# Angle: -1.02 radians, Average Distance: 24.6929
# Angle: -1.01 radians, Average Distance: 24.6076
# Angle: -1.01 radians, Average Distance: 24.5203
# Angle: -1.00 radians, Average Distance: 24.4267
# Angle: -1.00 radians, Average Distance: 24.3311
# Angle: -0.99 radians, Average Distance: 24.2388
# Angle: -0.99 radians, Average Distance: 24.1467
# Angle: -0.99 radians, Average Distance: 24.0566
# Angle: -0.98 radians, Average Distance: 23.9684
# Angle: -0.98 radians, Average Distance: 23.8798
# Angle: -0.97 radians, Average Distance: 23.7884
# Angle: -0.97 radians, Average Distance: 23.6939
# Angle: -0.96 radians, Average Distance: 23.6035
# Angle: -0.96 radians, Average Distance: 23.5175
# Angle: -0.96 radians, Average Distance: 23.4362
# Angle: -0.95 radians, Average Distance: 23.3568
# Angle: -0.95 radians, Average Distance: 23.2815
# Angle: -0.94 radians, Average Distance: 23.2089
# Angle: -0.94 radians, Average Distance: 23.1331
# Angle: -0.93 radians, Average Distance: 23.0600
# Angle: -0.93 radians, Average Distance: 22.9914
# Angle: -0.93 radians, Average Distance: 22.9248
# Angle: -0.92 radians, Average Distance: 22.8563
# Angle: -0.92 radians, Average Distance: 22.7855
# Angle: -0.91 radians, Average Distance: 22.7163
# Angle: -0.91 radians, Average Distance: 22.6469
# Angle: -0.90 radians, Average Distance: 22.5783
# Angle: -0.90 radians, Average Distance: 22.5140
# Angle: -0.89 radians, Average Distance: 22.4520
# Angle: -0.89 radians, Average Distance: 22.3881
# Angle: -0.89 radians, Average Distance: 22.3265
# Angle: -0.88 radians, Average Distance: 22.2619
# Angle: -0.88 radians, Average Distance: 22.1928
# Angle: -0.87 radians, Average Distance: 22.1251
# Angle: -0.87 radians, Average Distance: 22.0517
# Angle: -0.86 radians, Average Distance: 21.9731
# Angle: -0.86 radians, Average Distance: 21.8919
# Angle: -0.86 radians, Average Distance: 21.8143
# Angle: -0.85 radians, Average Distance: 21.7403
# Angle: -0.85 radians, Average Distance: 21.6663
# Angle: -0.84 radians, Average Distance: 21.5822
# Angle: -0.84 radians, Average Distance: 21.4888
# Angle: -0.83 radians, Average Distance: 21.3975
# Angle: -0.83 radians, Average Distance: 21.3082
# Angle: -0.82 radians, Average Distance: 21.2198
# Angle: -0.82 radians, Average Distance: 21.1312
# Angle: -0.82 radians, Average Distance: 21.0377
# Angle: -0.81 radians, Average Distance: 20.9495
# Angle: -0.81 radians, Average Distance: 20.8655
# Angle: -0.80 radians, Average Distance: 20.7875
# Angle: -0.80 radians, Average Distance: 20.7140
# Angle: -0.79 radians, Average Distance: 20.6404
# Angle: -0.79 radians, Average Distance: 20.5684
# Angle: -0.79 radians, Average Distance: 20.4997
# Angle: -0.78 radians, Average Distance: 20.4357
# Angle: -0.78 radians, Average Distance: 20.3714
# Angle: -0.77 radians, Average Distance: 20.3029
# Angle: -0.77 radians, Average Distance: 20.2275
# Angle: -0.76 radians, Average Distance: 20.1471
# Angle: -0.76 radians, Average Distance: 20.0637
# Angle: -0.75 radians, Average Distance: 19.9757
# Angle: -0.75 radians, Average Distance: 19.8786
# Angle: -0.75 radians, Average Distance: 19.7797
# Angle: -0.74 radians, Average Distance: 19.6770
# Angle: -0.74 radians, Average Distance: 19.5696
# Angle: -0.73 radians, Average Distance: 19.4517
# Angle: -0.73 radians, Average Distance: 19.3368
# Angle: -0.72 radians, Average Distance: 19.2251
# Angle: -0.72 radians, Average Distance: 19.1029
# Angle: -0.72 radians, Average Distance: 18.9727
# Angle: -0.71 radians, Average Distance: 18.8326
# Angle: -0.71 radians, Average Distance: 18.6918
# Angle: -0.70 radians, Average Distance: 18.5547
# Angle: -0.70 radians, Average Distance: 18.4199
# Angle: -0.69 radians, Average Distance: 18.2774
# Angle: -0.69 radians, Average Distance: 18.1354
# Angle: -0.69 radians, Average Distance: 17.9956
# Angle: -0.68 radians, Average Distance: 17.8555
# Angle: -0.68 radians, Average Distance: 17.7151
# Angle: -0.67 radians, Average Distance: 17.5756
# Angle: -0.67 radians, Average Distance: 17.4310
# Angle: -0.66 radians, Average Distance: 17.2878
# Angle: -0.66 radians, Average Distance: 17.1488
# Angle: -0.65 radians, Average Distance: 17.0173
# Angle: -0.65 radians, Average Distance: 16.8889
# Angle: -0.65 radians, Average Distance: 16.7547
# Angle: -0.64 radians, Average Distance: 16.6210
# Angle: -0.64 radians, Average Distance: 16.4920
# Angle: -0.63 radians, Average Distance: 16.3667
# Angle: -0.63 radians, Average Distance: 16.2473
# Angle: -0.62 radians, Average Distance: 16.1320
# Angle: -0.62 radians, Average Distance: 16.0187
# Angle: -0.62 radians, Average Distance: 15.9111
# Angle: -0.61 radians, Average Distance: 15.7992
# Angle: -0.61 radians, Average Distance: 15.6793
# Angle: -0.60 radians, Average Distance: 15.5605
# Angle: -0.60 radians, Average Distance: 15.4442
# Angle: -0.59 radians, Average Distance: 15.3338
# Angle: -0.59 radians, Average Distance: 15.2258
# Angle: -0.58 radians, Average Distance: 15.1125
# Angle: -0.58 radians, Average Distance: 14.9963
# Angle: -0.58 radians, Average Distance: 14.8764
# Angle: -0.57 radians, Average Distance: 14.7612
# Angle: -0.57 radians, Average Distance: 14.6511
# Angle: -0.56 radians, Average Distance: 14.5445
# Angle: -0.56 radians, Average Distance: 14.4400
# Angle: -0.55 radians, Average Distance: 14.3421
# Angle: -0.55 radians, Average Distance: 14.2440
# Angle: -0.55 radians, Average Distance: 14.1529
# Angle: -0.54 radians, Average Distance: 14.0659
# Angle: -0.54 radians, Average Distance: 13.9841
# Angle: -0.53 radians, Average Distance: 13.9031
# Angle: -0.53 radians, Average Distance: 13.8155
# Angle: -0.52 radians, Average Distance: 13.7333
# Angle: -0.52 radians, Average Distance: 13.6568
# Angle: -0.51 radians, Average Distance: 13.5824
# Angle: -0.51 radians, Average Distance: 13.5114
# Angle: -0.51 radians, Average Distance: 13.4325
# Angle: -0.50 radians, Average Distance: 13.3561
# Angle: -0.50 radians, Average Distance: 13.2857
# Angle: -0.49 radians, Average Distance: 13.2187
# Angle: -0.49 radians, Average Distance: 13.1551
# Angle: -0.48 radians, Average Distance: 13.0951
# Angle: -0.48 radians, Average Distance: 13.0427
# Angle: -0.48 radians, Average Distance: 12.9910
# Angle: -0.47 radians, Average Distance: 12.9404
# Angle: -0.47 radians, Average Distance: 12.8922
# Angle: -0.46 radians, Average Distance: 12.8446
# Angle: -0.46 radians, Average Distance: 12.7898
# Angle: -0.45 radians, Average Distance: 12.7322
# Angle: -0.45 radians, Average Distance: 12.6747
# Angle: -0.45 radians, Average Distance: 12.6234
# Angle: -0.44 radians, Average Distance: 12.5768
# Angle: -0.44 radians, Average Distance: 12.5376
# Angle: -0.43 radians, Average Distance: 12.5077
# Angle: -0.43 radians, Average Distance: 12.4833
# Angle: -0.42 radians, Average Distance: 12.4654
# Angle: -0.42 radians, Average Distance: 12.4479
# Angle: -0.41 radians, Average Distance: 12.4163
# Angle: -0.41 radians, Average Distance: 12.3811
# Angle: -0.41 radians, Average Distance: 12.3505
# Angle: -0.40 radians, Average Distance: 12.3124
# Angle: -0.40 radians, Average Distance: 12.2780
# Angle: -0.39 radians, Average Distance: 12.2457
# Angle: -0.39 radians, Average Distance: 12.2170
# Angle: -0.38 radians, Average Distance: 12.1908
# Angle: -0.38 radians, Average Distance: 12.1660
# Angle: -0.38 radians, Average Distance: 12.1423
# Angle: -0.37 radians, Average Distance: 12.1251
# Angle: -0.37 radians, Average Distance: 12.1159
# Angle: -0.36 radians, Average Distance: 12.1144
# Angle: -0.36 radians, Average Distance: 12.1113
# Angle: -0.35 radians, Average Distance: 12.1087
# Angle: -0.35 radians, Average Distance: 12.1014
# Angle: -0.34 radians, Average Distance: 12.0936
# Angle: -0.34 radians, Average Distance: 12.0831
# Angle: -0.34 radians, Average Distance: 12.0741
# Angle: -0.33 radians, Average Distance: 12.0526
# Angle: -0.33 radians, Average Distance: 12.0197
# Angle: -0.32 radians, Average Distance: 12.0018
# Angle: -0.32 radians, Average Distance: 11.9847
# Angle: -0.31 radians, Average Distance: 11.9708
# Angle: -0.31 radians, Average Distance: 11.9606
# Angle: -0.31 radians, Average Distance: 11.9536
# Angle: -0.30 radians, Average Distance: 11.9485
# Angle: -0.30 radians, Average Distance: 11.9392
# Angle: -0.29 radians, Average Distance: 11.9288
# Angle: -0.29 radians, Average Distance: 11.9171
# Angle: -0.28 radians, Average Distance: 11.9067
# Angle: -0.28 radians, Average Distance: 11.9005
# Angle: -0.27 radians, Average Distance: 11.8908
# Angle: -0.27 radians, Average Distance: 11.8756
# Angle: -0.27 radians, Average Distance: 11.8593
# Angle: -0.26 radians, Average Distance: 11.8432
# Angle: -0.26 radians, Average Distance: 11.8223
# Angle: -0.25 radians, Average Distance: 11.8039
# Angle: -0.25 radians, Average Distance: 11.7844
# Angle: -0.24 radians, Average Distance: 11.7518
# Angle: -0.24 radians, Average Distance: 11.7162
# Angle: -0.24 radians, Average Distance: 11.6865
# Angle: -0.23 radians, Average Distance: 11.6604
# Angle: -0.23 radians, Average Distance: 11.6401
# Angle: -0.22 radians, Average Distance: 11.6257
# Angle: -0.22 radians, Average Distance: 11.6122
# Angle: -0.21 radians, Average Distance: 11.6018
# Angle: -0.21 radians, Average Distance: 11.5788
# Angle: -0.21 radians, Average Distance: 11.5494
# Angle: -0.20 radians, Average Distance: 11.5078
# Angle: -0.20 radians, Average Distance: 11.4596
# Angle: -0.19 radians, Average Distance: 11.4146
# Angle: -0.19 radians, Average Distance: 11.3706
# Angle: -0.18 radians, Average Distance: 11.3304
# Angle: -0.18 radians, Average Distance: 11.2888
# Angle: -0.17 radians, Average Distance: 11.2482
# Angle: -0.17 radians, Average Distance: 11.1851
# Angle: -0.17 radians, Average Distance: 11.0985
# Angle: -0.16 radians, Average Distance: 10.9947
# Angle: -0.16 radians, Average Distance: 10.8890
# Angle: -0.15 radians, Average Distance: 10.7754
# Angle: -0.15 radians, Average Distance: 10.6608
# Angle: -0.14 radians, Average Distance: 10.5531
# Angle: -0.14 radians, Average Distance: 10.4535
# Angle: -0.14 radians, Average Distance: 10.3620
# Angle: -0.13 radians, Average Distance: 10.2715
# Angle: -0.13 radians, Average Distance: 10.1779
# Angle: -0.12 radians, Average Distance: 10.0862
# Angle: -0.12 radians, Average Distance: 10.0000
# Angle: -0.11 radians, Average Distance: 9.9178
# Angle: -0.11 radians, Average Distance: 9.8305
# Angle: -0.10 radians, Average Distance: 9.7421
# Angle: -0.10 radians, Average Distance: 9.6456
# Angle: -0.10 radians, Average Distance: 9.5576
# Angle: -0.09 radians, Average Distance: 9.4770
# Angle: -0.09 radians, Average Distance: 9.4031
# Angle: -0.08 radians, Average Distance: 9.3352
# Angle: -0.08 radians, Average Distance: 9.2520
# Angle: -0.07 radians, Average Distance: 9.1481
# Angle: -0.07 radians, Average Distance: 9.0484
# Angle: -0.07 radians, Average Distance: 8.9508
# Angle: -0.06 radians, Average Distance: 8.8435
# Angle: -0.06 radians, Average Distance: 8.6925
# Angle: -0.05 radians, Average Distance: 8.5140
# Angle: -0.05 radians, Average Distance: 8.3382
# Angle: -0.04 radians, Average Distance: 8.1270
# Angle: -0.04 radians, Average Distance: 7.8800
# Angle: -0.03 radians, Average Distance: 7.6326
# Angle: -0.03 radians, Average Distance: 7.3869
# Angle: -0.03 radians, Average Distance: 7.1429
# Angle: -0.02 radians, Average Distance: 6.9007
# Angle: -0.02 radians, Average Distance: 6.6606
# Angle: -0.01 radians, Average Distance: 6.4227
# Angle: -0.01 radians, Average Distance: 6.1878
# Angle: -0.00 radians, Average Distance: 5.9560
# Angle: -0.00 radians, Average Distance: 5.7295
# Angle: 0.00 radians, Average Distance: 5.5073
# Angle: 0.01 radians, Average Distance: 5.2907
# Angle: 0.01 radians, Average Distance: 5.0848
# Angle: 0.02 radians, Average Distance: 4.9159
# Angle: 0.02 radians, Average Distance: 4.9755
# Angle: 0.03 radians, Average Distance: 5.1644
# Angle: 0.02 radians, Average Distance: 4.9755
# Angle: 0.02 radians, Average Distance: 4.9159
# Angle: 0.02 radians, Average Distance: 4.9755
# Angle: 0.03 radians, Average Distance: 5.1644
# Angle: 0.03 radians, Average Distance: 5.3969
# Angle: 0.03 radians, Average Distance: 5.6484
# Angle: 0.04 radians, Average Distance: 5.9070
# Angle: 0.04 radians, Average Distance: 6.1684
# Angle: 0.05 radians, Average Distance: 6.4319
# Angle: 0.05 radians, Average Distance: 6.6971
# Angle: 0.06 radians, Average Distance: 6.9617
# Angle: 0.06 radians, Average Distance: 7.2273
# Angle: 0.07 radians, Average Distance: 7.4941
# Angle: 0.07 radians, Average Distance: 7.7529
# Angle: 0.07 radians, Average Distance: 8.0129
# Angle: 0.08 radians, Average Distance: 8.2733
# Angle: 0.08 radians, Average Distance: 8.5309
# Angle: 0.09 radians, Average Distance: 8.7325
# Angle: 0.09 radians, Average Distance: 8.9211
# Angle: 0.10 radians, Average Distance: 9.1086
# Angle: 0.10 radians, Average Distance: 9.2633
# Angle: 0.10 radians, Average Distance: 9.3988
# Angle: 0.11 radians, Average Distance: 9.5371
# Angle: 0.11 radians, Average Distance: 9.6715
# Angle: 0.12 radians, Average Distance: 9.8048
# Angle: 0.12 radians, Average Distance: 9.9043
# Angle: 0.13 radians, Average Distance: 10.0081
# Angle: 0.13 radians, Average Distance: 10.1180
# Angle: 0.14 radians, Average Distance: 10.2295
# Angle: 0.14 radians, Average Distance: 10.3505
# Angle: 0.14 radians, Average Distance: 10.4816
# Angle: 0.15 radians, Average Distance: 10.6096
# Angle: 0.15 radians, Average Distance: 10.7400
# Angle: 0.16 radians, Average Distance: 10.8647
# Angle: 0.16 radians, Average Distance: 10.9836
# Angle: 0.17 radians, Average Distance: 11.1047
# Angle: 0.17 radians, Average Distance: 11.2346
# Angle: 0.17 radians, Average Distance: 11.3661
# Angle: 0.18 radians, Average Distance: 11.4967
# Angle: 0.18 radians, Average Distance: 11.6299
# Angle: 0.19 radians, Average Distance: 11.7641
# Angle: 0.19 radians, Average Distance: 11.8934
# Angle: 0.20 radians, Average Distance: 12.0251
# Angle: 0.20 radians, Average Distance: 12.1612
# Angle: 0.21 radians, Average Distance: 12.2918
# Angle: 0.21 radians, Average Distance: 12.4279
# Angle: 0.21 radians, Average Distance: 12.5521
# Angle: 0.22 radians, Average Distance: 12.6506
# Angle: 0.22 radians, Average Distance: 12.7343
# Angle: 0.23 radians, Average Distance: 12.8132
# Angle: 0.23 radians, Average Distance: 12.8868
# Angle: 0.24 radians, Average Distance: 12.9569
# Angle: 0.24 radians, Average Distance: 13.0283
# Angle: 0.24 radians, Average Distance: 13.0989
# Angle: 0.25 radians, Average Distance: 13.1681
# Angle: 0.25 radians, Average Distance: 13.2383
# Angle: 0.26 radians, Average Distance: 13.2990
# Angle: 0.26 radians, Average Distance: 13.3577
# Angle: 0.27 radians, Average Distance: 13.4119
# Angle: 0.27 radians, Average Distance: 13.4666
# Angle: 0.27 radians, Average Distance: 13.5251
# Angle: 0.28 radians, Average Distance: 13.5940
# Angle: 0.28 radians, Average Distance: 13.6744
# Angle: 0.29 radians, Average Distance: 13.7611
# Angle: 0.29 radians, Average Distance: 13.8367
# Angle: 0.30 radians, Average Distance: 13.9169
# Angle: 0.30 radians, Average Distance: 14.0034
# Angle: 0.31 radians, Average Distance: 14.0931
# Angle: 0.31 radians, Average Distance: 14.1844
# Angle: 0.31 radians, Average Distance: 14.2671
# Angle: 0.32 radians, Average Distance: 14.3505
# Angle: 0.32 radians, Average Distance: 14.4322
# Angle: 0.33 radians, Average Distance: 14.5057
# Angle: 0.33 radians, Average Distance: 14.5778
# Angle: 0.34 radians, Average Distance: 14.6605
# Angle: 0.34 radians, Average Distance: 14.7458
# Angle: 0.34 radians, Average Distance: 14.8230
# Angle: 0.35 radians, Average Distance: 14.8962
# Angle: 0.35 radians, Average Distance: 14.9648
# Angle: 0.36 radians, Average Distance: 15.0284
# Angle: 0.36 radians, Average Distance: 15.0878
# Angle: 0.37 radians, Average Distance: 15.1499
# Angle: 0.37 radians, Average Distance: 15.2124
# Angle: 0.38 radians, Average Distance: 15.2760
# Angle: 0.38 radians, Average Distance: 15.3478
# Angle: 0.38 radians, Average Distance: 15.4211
# Angle: 0.39 radians, Average Distance: 15.4986
# Angle: 0.39 radians, Average Distance: 15.5812
# Angle: 0.40 radians, Average Distance: 15.6659
# Angle: 0.40 radians, Average Distance: 15.7561
# Angle: 0.41 radians, Average Distance: 15.8446
# Angle: 0.41 radians, Average Distance: 15.9275
# Angle: 0.41 radians, Average Distance: 16.0080
# Angle: 0.42 radians, Average Distance: 16.0814
# Angle: 0.42 radians, Average Distance: 16.1540
# Angle: 0.43 radians, Average Distance: 16.2286
# Angle: 0.43 radians, Average Distance: 16.3063
# Angle: 0.44 radians, Average Distance: 16.3773
# Angle: 0.44 radians, Average Distance: 16.4509
# Angle: 0.45 radians, Average Distance: 16.5193
# Angle: 0.45 radians, Average Distance: 16.5867
# Angle: 0.45 radians, Average Distance: 16.6502
# Angle: 0.46 radians, Average Distance: 16.7150
# Angle: 0.46 radians, Average Distance: 16.7796
# Angle: 0.47 radians, Average Distance: 16.8465
# Angle: 0.47 radians, Average Distance: 16.9194
# Angle: 0.48 radians, Average Distance: 16.9896
# Angle: 0.48 radians, Average Distance: 17.0613
# Angle: 0.48 radians, Average Distance: 17.1345
# Angle: 0.49 radians, Average Distance: 17.2101
# Angle: 0.49 radians, Average Distance: 17.2832
# Angle: 0.50 radians, Average Distance: 17.3532
# Angle: 0.50 radians, Average Distance: 17.4163
# Angle: 0.51 radians, Average Distance: 17.4744
# Angle: 0.51 radians, Average Distance: 17.5229
# Angle: 0.51 radians, Average Distance: 17.5726
# Angle: 0.52 radians, Average Distance: 17.6259
# Angle: 0.52 radians, Average Distance: 17.6713
# Angle: 0.53 radians, Average Distance: 17.7223
# Angle: 0.53 radians, Average Distance: 17.7699
# Angle: 0.54 radians, Average Distance: 17.8195
# Angle: 0.54 radians, Average Distance: 17.8760
# Angle: 0.55 radians, Average Distance: 17.9394
# Angle: 0.55 radians, Average Distance: 18.0086
# Angle: 0.55 radians, Average Distance: 18.0765
# Angle: 0.56 radians, Average Distance: 18.1417
# Angle: 0.56 radians, Average Distance: 18.2125
# Angle: 0.57 radians, Average Distance: 18.2843
# Angle: 0.57 radians, Average Distance: 18.3513
# Angle: 0.58 radians, Average Distance: 18.4205
# Angle: 0.58 radians, Average Distance: 18.4886
# Angle: 0.58 radians, Average Distance: 18.5500
# Angle: 0.59 radians, Average Distance: 18.6155
# Angle: 0.59 radians, Average Distance: 18.6837
# Angle: 0.60 radians, Average Distance: 18.7457
# Angle: 0.60 radians, Average Distance: 18.8132
# Angle: 0.61 radians, Average Distance: 18.8822
# Angle: 0.61 radians, Average Distance: 18.9489
# Angle: 0.62 radians, Average Distance: 19.0102
# Angle: 0.62 radians, Average Distance: 19.0679
# Angle: 0.62 radians, Average Distance: 19.1300
# Angle: 0.63 radians, Average Distance: 19.1933
# Angle: 0.63 radians, Average Distance: 19.2570
# Angle: 0.64 radians, Average Distance: 19.3230
# Angle: 0.64 radians, Average Distance: 19.3834
# Angle: 0.65 radians, Average Distance: 19.4443
# Angle: 0.65 radians, Average Distance: 19.5018
# Angle: 0.65 radians, Average Distance: 19.5610
# Angle: 0.66 radians, Average Distance: 19.6121
# Angle: 0.66 radians, Average Distance: 19.6528
# Angle: 0.67 radians, Average Distance: 19.6949
# Angle: 0.67 radians, Average Distance: 19.7424
# Angle: 0.68 radians, Average Distance: 19.7920
# Angle: 0.68 radians, Average Distance: 19.8422
# Angle: 0.69 radians, Average Distance: 19.8962
# Angle: 0.69 radians, Average Distance: 19.9438
# Angle: 0.69 radians, Average Distance: 19.9920
# Angle: 0.70 radians, Average Distance: 20.0407
# Angle: 0.70 radians, Average Distance: 20.0892
# Angle: 0.71 radians, Average Distance: 20.1388
# Angle: 0.71 radians, Average Distance: 20.1941
# Angle: 0.72 radians, Average Distance: 20.2482
# Angle: 0.72 radians, Average Distance: 20.2968
# Angle: 0.72 radians, Average Distance: 20.3458
# Angle: 0.73 radians, Average Distance: 20.3901
# Angle: 0.73 radians, Average Distance: 20.4385
